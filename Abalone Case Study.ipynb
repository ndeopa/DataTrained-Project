# %% [markdown]
# # Abalone Case Study

# %% [markdown]
# The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task. Other measurements, which are easier to obtain, are used to predict the age.

# %% [markdown]
# ### Attribute Information

# %% [markdown]
# Given is the attribute name, attribute type, the measurement unit and a brief description. The number of rings is the value to predict.

# %% [markdown]
# ## Name / Data Type / Measurement Unit / Description

# %% [markdown]
# Sex / nominal / -- / M, F, and I (infant) Length / continuous / mm / Longest shell measurement Diameter / continuous / mm / perpendicular to length Height / continuous / mm / with meat in shell Whole weight / continuous / grams / whole abalone Shucked weight / continuous / grams / weight of meat Viscera weight / continuous / grams / gut weight (after bleeding) Shell weight / continuous / grams / after being dried Rings / integer / -- / +1.5 gives the age in years. You have to predict the rings of each abalone which will lead us to the age of that abalone.

# %% [markdown]
# ### Loading the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

from sklearn.linear_model import Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor

from sklearn.neighbors import KNeighborsRegressor

from sklearn.ensemble import RandomForestRegressor


from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('dataset/Abalone.csv')

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
#Lets check whether there are null values or not
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# No null value present in the dataset.

# %%
#Lets check the  Datatypes of each column
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# ### Explore the Data

# %% [markdown]
# Let's actually look at the data now.

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %% [markdown]
# Two things stands out: first, the minimum height is 0, which must be a typo. Second, the smallest weight is (after rescaling) significantly less than a gram. Let's sort the first few values sorted by height.

# %%
df.sort_values(by=["Height"]).head(15)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 3996   I   0.315     0.230   0.000        0.1340          0.0575
# 1257   I   0.430     0.340   0.000        0.4280          0.2065
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 2169   I   0.165     0.115   0.015        0.0145          0.0055
# 1174   F   0.635     0.495   0.015        1.1565          0.5115
# 3902   I   0.160     0.120   0.020        0.0180          0.0075
# 694    I   0.165     0.110   0.020        0.0190          0.0065
# 1987   I   0.160     0.110   0.025        0.0195          0.0075
# 2381   M   0.155     0.115   0.025        0.0240          0.0090
# 3190   I   0.200     0.145   0.025        0.0345          0.0110
# 720    I   0.160     0.110   0.025        0.0180          0.0065
# 719    I   0.150     0.100   0.025        0.0150          0.0045
# 2171   I   0.190     0.130   0.030        0.0295          0.0155
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 2172   I   0.215     0.150   0.030        0.0385          0.0115
#
#       Viscera weight  Shell weight  Rings
# 3996          0.0285        0.3505      6
# 1257          0.0860        0.1150      8
# 236           0.0005        0.0015      1
# 2169          0.0030        0.0050      4
# 1174          0.3080        0.2885      9
# 3902          0.0045        0.0050      4
# 694           0.0025        0.0050      4
# 1987          0.0050        0.0060      4
# 2381          0.0050        0.0075      5
# 3190          0.0075        0.0100      5
# 720           0.0055        0.0050      3
# 719           0.0040        0.0050      2
# 2171          0.0150        0.0100      6
# 238           0.0020        0.0030      3
# 2172          0.0050        0.0100      5

# %% [markdown]
# It's just two entries with height 0, so I think it's safe to drop them. While we're here entry 1174 is a clear outlier. Let's handle that later.

# %%
df = df.loc[df["Height"] != 0.0]

# %%
df.sort_values(by=["Whole weight"]).head(15)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 236    I   0.075     0.055   0.010        0.0020          0.0010
# 238    I   0.110     0.090   0.030        0.0080          0.0025
# 2114   I   0.130     0.095   0.035        0.0105          0.0050
# 237    I   0.130     0.100   0.030        0.0130          0.0045
# 1429   I   0.140     0.105   0.035        0.0140          0.0055
# 3899   I   0.140     0.105   0.035        0.0145          0.0050
# 2169   I   0.165     0.115   0.015        0.0145          0.0055
# 719    I   0.150     0.100   0.025        0.0150          0.0045
# 526    M   0.155     0.110   0.040        0.0155          0.0065
# 696    I   0.155     0.105   0.050        0.0175          0.0050
# 720    I   0.160     0.110   0.025        0.0180          0.0065
# 3902   I   0.160     0.120   0.020        0.0180          0.0075
# 694    I   0.165     0.110   0.020        0.0190          0.0065
# 1987   I   0.160     0.110   0.025        0.0195          0.0075
# 239    I   0.160     0.120   0.035        0.0210          0.0075
#
#       Viscera weight  Shell weight  Rings
# 236           0.0005        0.0015      1
# 238           0.0020        0.0030      3
# 2114          0.0065        0.0035      4
# 237           0.0030        0.0040      3
# 1429          0.0025        0.0040      3
# 3899          0.0035        0.0050      4
# 2169          0.0030        0.0050      4
# 719           0.0040        0.0050      2
# 526           0.0030        0.0050      3
# 696           0.0035        0.0050      4
# 720           0.0055        0.0050      3
# 3902          0.0045        0.0050      4
# 694           0.0025        0.0050      4
# 1987          0.0050        0.0060      4
# 239           0.0045        0.0050      5

# %% [markdown]
# Looking at this table I suspect that the low weight entry is real, since it only has one ring and has small length, diameter, and height

# %% [markdown]
# Let's construct a correlation matrix and a heatmap for our data.

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986802  0.828108      0.925217        0.897859
# Diameter        0.986802  1.000000  0.834298      0.925414        0.893108
# Height          0.828108  0.834298  1.000000      0.819886        0.775621
# Whole weight    0.925217  0.925414  0.819886      1.000000        0.969389
# Shucked weight  0.897859  0.893108  0.775621      0.969389        1.000000
# Viscera weight  0.902960  0.899672  0.798908      0.966354        0.931924
# Shell weight    0.898419  0.906084  0.819596      0.955924        0.883129
# Rings           0.556464  0.574418  0.557625      0.540151        0.420597
#
#                 Viscera weight  Shell weight     Rings
# Length                0.902960      0.898419  0.556464
# Diameter              0.899672      0.906084  0.574418
# Height                0.798908      0.819596  0.557625
# Whole weight          0.966354      0.955924  0.540151
# Shucked weight        0.931924      0.883129  0.420597
# Viscera weight        1.000000      0.908186  0.503562
# Shell weight          0.908186      1.000000  0.627928
# Rings                 0.503562      0.627928  1.000000

# %%
plt.figure(figsize = (15,6))
corr = df.corr()
ax = sns.heatmap(
    corr, 
    annot=True  
)

# %% [markdown]
# Almost everything is strongly correlated with everything else, except ring count! :( Assuming body proportions don't vary much between different abalone this makes sense.
#
# All of the features associated with weight are pretty much perfectly correlated with each other, with pearson coefficients > 0.95 for whole weight. This isn't surprising since they're just the weights of different parts of the same abalone. I think we can safely drop the shucked weight, viscera weight, and shell weight and just keep whole weight (PCA is probably overkill).
#
# Length and diameter are just about perfectly correlated. The circumfrence of an ellipse is proportional to its length with the constant of proportionality determined by its eccentricity, so no surprise there. Height is strongly correlated with the remaining features, but not as strongly as, say, length with diameter. We'll replace these three features with their geometric mean. While keeping length, diameter, and height can only help with prediction, I think the benefits gained of an easier to interpret model outweight the marginal gain of predictability from keeping them.

# %%
#Lets describe the abalone dataset
df.describe()
# Out:
#             Length    Diameter       Height  Whole weight  Shucked weight  \
# count  4175.000000  4175.00000  4175.000000   4175.000000     4175.000000
# mean      0.524065     0.40794     0.139583      0.829005        0.359476
# std       0.120069     0.09922     0.041725      0.490349        0.221954
# min       0.075000     0.05500     0.010000      0.002000        0.001000
# 25%       0.450000     0.35000     0.115000      0.442250        0.186250
# 50%       0.545000     0.42500     0.140000      0.800000        0.336000
# 75%       0.615000     0.48000     0.165000      1.153500        0.502000
# max       0.815000     0.65000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4175.000000   4175.000000  4175.000000
# mean         0.180653      0.238834     9.935090
# std          0.109605      0.139212     3.224227
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.328750    11.000000
# max          0.760000      1.005000    29.000000

# %%
# checkig the values of sex

df['Sex'].value_counts()
# Out:
# M    1528
# I    1340
# F    1307
# Name: Sex, dtype: int64

# %%
#Lets draw a bar graph for Rings and Sex
plt.figure(figsize=(10,8))
sns.barplot(x="Sex",y="Rings",data=df)
plt.show()

# %%
# plotting a hue plot
sns.set_theme(style='whitegrid')
plt.rcParams['figure.figsize'] = (18, 8)
sns.boxplot(df['Rings'], df['Length'], hue = df['Sex'], palette = 'pastel')
plt.title('Rings vs length and sex', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rings vs length and sex')

# %% [markdown]
# Here we can see that there are some outliers present in the dataset

# %%
# rings vs diameter and sex

plt.rcParams['figure.figsize'] = (20, 8)
sns.violinplot(df['Rings'], df['Diameter'], hue = df['Sex'], palette = 'Set1')
plt.title('Rings vs diameter and sex', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rings vs diameter and sex')

# %%
# rings vs height and sex

plt.rcParams['figure.figsize'] = (18, 8)
sns.boxenplot(df['Rings'], df['Height'], hue = df['Sex'], palette = 'Set2')
plt.title('Rings vs height and sex', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Rings vs height and sex')

# %%
# ring vs weight

plt.rcParams['figure.figsize'] = (18, 10)
sns.swarmplot(df['Rings'], df['Whole weight'])
plt.title('Rings vs weight')
# Out:
# Text(0.5, 1.0, 'Rings vs weight')

# %% [markdown]
# Here we can see the Rings( age) according to the whole weight of the abalone and we can see that most of the rings are between 8 to 11 rings

# %%
# ring vs shucked weight

plt.rcParams['figure.figsize'] = (18, 10)
sns.swarmplot(df['Rings'], df['Shucked weight'], palette = 'dark')
plt.title('Rings vs shucked weight')
# Out:
# Text(0.5, 1.0, 'Rings vs shucked weight')

# %% [markdown]
# Here we can see the Rings( age) according to the weight of meat i,e.(Shucked weight)

# %%
# ring vs viscera weight

plt.rcParams['figure.figsize'] = (18, 10)
sns.stripplot(df['Rings'], df['Viscera weight'])
plt.title('Rings vs Viscera Weight')
# Out:
# Text(0.5, 1.0, 'Rings vs Viscera Weight')

# %% [markdown]
# Here we can see the Rings( age) according to the Viscera weight(gut weight (after bleeding)) and most of the rings are in between 10 to 13

# %%
sns.pairplot(df)

# %%
import math as m
df['Volume apprx'] = df['Length'] * df['Diameter'] * df['Height'] * m.pi * 4/3
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings  Volume apprx
# 0             0.1010        0.1500     15      0.066087
# 1             0.0485        0.0700      7      0.034966
# 2             0.1415        0.2100      9      0.125877
# 3             0.1140        0.1550     10      0.084090
# 4             0.0395        0.0550      7      0.028199
# ...              ...           ...    ...           ...
# 4172          0.2390        0.2490     11      0.175725
# 4173          0.2145        0.2605     10      0.146800
# 4174          0.2875        0.3080      9      0.244730
# 4175          0.2610        0.2960     10      0.190459
# 4176          0.3765        0.4950     12      0.321866
#
# [4175 rows x 10 columns]

# %% [markdown]
# As little difference between Male and Female it would be useful to use Adult/Infant flag for age prediction

# %%
# df['Age category'] = np.where(df['Sex'] == 'I','Infant', 'Adult')
df['Age category'] = np.where(df['Sex'] == 'I',0, 1)
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings  Volume apprx  Age category
# 0             0.1010        0.1500     15      0.066087             1
# 1             0.0485        0.0700      7      0.034966             1
# 2             0.1415        0.2100      9      0.125877             1
# 3             0.1140        0.1550     10      0.084090             1
# 4             0.0395        0.0550      7      0.028199             0
# ...              ...           ...    ...           ...           ...
# 4172          0.2390        0.2490     11      0.175725             1
# 4173          0.2145        0.2605     10      0.146800             1
# 4174          0.2875        0.3080      9      0.244730             1
# 4175          0.2610        0.2960     10      0.190459             1
# 4176          0.3765        0.4950     12      0.321866             1
#
# [4175 rows x 11 columns]

# %%
df=df.drop('Sex',axis=1)

# %% [markdown]
# ### Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
df=df[(z<3).all(axis=1)]

# %%
#Lets check the skewness
df.skew()
#From below output it is clear that skewness exist
# Out:
# Length           -0.625223
# Diameter         -0.601660
# Height           -0.248509
# Whole weight      0.326509
# Shucked weight    0.454668
# Viscera weight    0.433292
# Shell weight      0.341021
# Rings             0.726752
# Volume apprx      0.377289
# Age category     -0.730831
# dtype: float64

# %%
#before treating skewnees lets divide the dataset into input and output
x=df.drop(columns=["Rings"])
y=df[["Rings"]]

# %%
#Now lets remove the skewness
for index in x.skew().index:
    if x.skew().loc[index]>0.5:
        x[index]=np.log1p(x[index])
    if x.skew().loc[index]<-0.5:
        x[index]=np.square(x[index])

# %%
#lets again check the skewness
x.skew()
# Out:
# Length           -0.122853
# Diameter         -0.084150
# Height           -0.248509
# Whole weight      0.326509
# Shucked weight    0.454668
# Viscera weight    0.433292
# Shell weight      0.341021
# Volume apprx      0.377289
# Age category     -0.730831
# dtype: float64

# %%
x.shape
# Out:
# (4025, 9)

# %%
y.shape
# Out:
# (4025, 1)

# %% [markdown]
# ### Now, splitting the data for Training & Testing

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=46)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()
x_train = scalar.fit_transform(x_train)
x_test = scalar.transform(x_test)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (2817, 9)
# (1208, 9)
# (2817, 1)
# (1208, 1)

# %%
LR=LinearRegression()
rf=RandomForestRegressor(n_estimators=50)
knn=KNeighborsRegressor(n_neighbors=19)
dtc=DecisionTreeRegressor()
ls=Lasso(alpha=0.01)
rd=Ridge(alpha=0.01)

# %%
model=[LR,rf,knn,dtc,ls,rd]

for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print("The Mean absolute error value of ",m ,"is. ")
    print("Mean absolute error: %.2f" % mean_absolute_error(y_test,predm))
    print()
    print("The Mean squared error value of ",m ,"is. ")
    print("Residual sum of squares (MSE): %.2f" % mean_squared_error(y_test,predm))
    print()
    print("The r2_score value of ",m ,"is. ")
    print("R2-score of : %.2f" % r2_score(y_test,predm))
    print()
    print("Now check with Cross validation\n")
    
    score=cross_val_score(m,x,y,cv=10)
    print("The score after cross_validation : ",score)
    print("The Mean score after cross_validation : ",score.mean())
    print('\n')
# Out:
# The Mean absolute error value of  LinearRegression() is.
# Mean absolute error: 1.46
#
# The Mean squared error value of  LinearRegression() is.
# Residual sum of squares (MSE): 3.90
#
# The r2_score value of  LinearRegression() is.
# R2-score of : 0.54
#
# Now check with Cross validation
#
# The score after cross_validation :  [0.55657907 0.38136409 0.32407229 0.16066823 0.33204197 0.49529427
#  0.42765167 0.43949975 0.50675819 0.50530688]
# The Mean score after cross_validation :  0.412923641647434
#
#
# The Mean absolute error value of  RandomForestRegressor(n_estimators=50) is.
# Mean absolute error: 1.47
#
# The Mean squared error value of  RandomForestRegressor(n_estimators=50) is.
# Residual sum of squares (MSE): 4.03
#
# The r2_score value of  RandomForestRegressor(n_estimators=50) is.
# R2-score of : 0.53
#
# Now check with Cross validation
#
# The score after cross_validation :  [0.48874462 0.39976064 0.40685778 0.08924858 0.29948228 0.48673917
#  0.53507397 0.41300592 0.5938037  0.47014317]
# The Mean score after cross_validation :  0.4182859842473162
#
#
# The Mean absolute error value of  KNeighborsRegressor(n_neighbors=19) is.
# Mean absolute error: 1.43
#
# The Mean squared error value of  KNeighborsRegressor(n_neighbors=19) is.
# Residual sum of squares (MSE): 4.06
#
# The r2_score value of  KNeighborsRegressor(n_neighbors=19) is.
# R2-score of : 0.52
#
# Now check with Cross validation
#
# The score after cross_validation :  [0.44217108 0.33317404 0.43739433 0.36907799 0.4596337  0.44513499
#  0.58632013 0.41581485 0.61336378 0.5246697 ]
# The Mean score after cross_validation :  0.4626754592373897
#
#
# The Mean absolute error value of  DecisionTreeRegressor() is.
# Mean absolute error: 2.04
#
# The Mean squared error value of  DecisionTreeRegressor() is.
# Residual sum of squares (MSE): 8.37
#
# The r2_score value of  DecisionTreeRegressor() is.
# R2-score of : 0.02
#
# Now check with Cross validation
#
# The score after cross_validation :  [ 8.53390530e-02 -1.26019877e-02 -2.19755615e-01 -9.65866600e-01
#  -5.42480138e-01  6.71203211e-02 -1.58278378e-01 -1.90839695e-04
#   2.30355433e-01 -5.76845807e-02]
# The Mean score after cross_validation :  -0.15740433320356878
#
#
# The Mean absolute error value of  Lasso(alpha=0.01) is.
# Mean absolute error: 1.46
#
# The Mean squared error value of  Lasso(alpha=0.01) is.
# Residual sum of squares (MSE): 3.90
#
# The r2_score value of  Lasso(alpha=0.01) is.
# R2-score of : 0.54
#
# Now check with Cross validation
#
# The score after cross_validation :  [0.4880303  0.23284923 0.28064985 0.21342199 0.32770486 0.39409517
#  0.42880131 0.38515911 0.45822819 0.42004665]
# The Mean score after cross_validation :  0.36289866731763876
#
#
# The Mean absolute error value of  Ridge(alpha=0.01) is.
# Mean absolute error: 1.46
#
# The Mean squared error value of  Ridge(alpha=0.01) is.
# Residual sum of squares (MSE): 3.90
#
# The r2_score value of  Ridge(alpha=0.01) is.
# R2-score of : 0.54
#
# Now check with Cross validation
#
# The score after cross_validation :  [0.55624888 0.3798992  0.32681217 0.16175394 0.33343578 0.49489802
#  0.42973677 0.43935638 0.50709462 0.50458338]
# The Mean score after cross_validation :  0.4133819137866556

# %% [markdown]
# ### Conclusion:

# %% [markdown]
# Minimum difference in r2 score and cross validation score is for KNN , so this is our best model as it's r2_score is 0.52 and after cross-validation it's score is : 0.46.

# %% [markdown]
# ## Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = [{"n_neighbors":range(1,40),
              "algorithm":['auto', 'ball_tree', 'kd_tree', 'brute'],
              "weights": ['uniform','distance'],
              "n_jobs":range(1,10)
             }]

# %%
model = KNeighborsRegressor()

# %%
grid = GridSearchCV(estimator=model,param_grid=parameters,cv=5,scoring='r2')

# %%
#Unable to Run This
# Fit it to the data
#grid.fit(x_train,y_train)
#Print the tuned parameters and score
#print("Tuned KNeighborsRegressor Parameters: {}".format(grid.best_params_))
#print("Best score is {}".format(grid.best_score_))

# %% [markdown]
# # Final modelling and evaluating using Best Parameteres.

# %%
m=KNeighborsRegressor(algorithm= 'auto', n_jobs= 1, n_neighbors = 24, weights= 'distance')
m.fit(x_train,y_train)
predm=m.predict(x_test)
print("The Mean absolute error value of ",m ,"is. ")
print("Mean absolute error: %.2f" % mean_absolute_error(y_test,predm))
print()
print("The Mean squared error value of ",m ,"is. ")
print("Residual sum of squares (MSE): %.2f" % mean_squared_error(y_test,predm))
print()
print("The r2_score value of ",m ,"is. ")
print("R2-score of : %.2f" % r2_score(y_test,predm))
print()
print("Now check with Cross validation\n")
    
score=cross_val_score(m,x,y,cv=10)
print("The score after cross_validation : ",score)
print("The Mean score after cross_validation : ",score.mean())
# Out:
# The Mean absolute error value of  KNeighborsRegressor(n_jobs=1, n_neighbors=24, weights='distance') is.
# Mean absolute error: 1.42
#
# The Mean squared error value of  KNeighborsRegressor(n_jobs=1, n_neighbors=24, weights='distance') is.
# Residual sum of squares (MSE): 3.99
#
# The r2_score value of  KNeighborsRegressor(n_jobs=1, n_neighbors=24, weights='distance') is.
# R2-score of : 0.53
#
# Now check with Cross validation
#
# The score after cross_validation :  [0.44641591 0.33077681 0.44896309 0.37381928 0.46340131 0.44189572
#  0.58424103 0.4210354  0.61510161 0.52389892]
# The Mean score after cross_validation :  0.4649549096740241

# %% [markdown]
# ### Final conclusion:

# %% [markdown]
# The final model has an R2score of 0.53.

# %% [markdown]
# ### Saving the model

# %%
#saving the model
model=joblib.dump(m,'knnmodel.obj')

# %% [markdown]
# ### Result:

# %%
loaded_model= joblib.load('knnmodel.obj')
result=loaded_model.score(x_test,y_test)
print(result)
# Out:
# 0.5326568127226404
